# %%
from scipy import stats
from scipy.stats import norm, skewnorm
import matplotlib.pyplot as plt

# %%
data = norm.rvs(size = 10000)
data
# Out:
# array([-0.9161989 ,  1.35348753,  0.22567553, ..., -1.56069176,
#        -0.72905555,  1.63827108], shape=(10000,))

# %%
plt.hist(data, bins = 20)
plt.title('Data')
# Out:
# Text(0.5, 1.0, 'Data')

# %%
fig, ax = plt.subplots()
stats.probplot(data, fit=True, plot=ax)
plt.show()

# %%
stats.shapiro(data)
# Out:
# c:\Users\Josef\anaconda3\envs\studyenvironment\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 10000.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=np.float64(0.9999256753592513), pvalue=np.float64(0.9961069128608772))

# %%
data2 = skewnorm.rvs(4, size=1000)

# %%
plt.hist(data2, bins=50)
plt.title('Data')
# Out:
# Text(0.5, 1.0, 'Data')

# %%
fig, ax = plt.subplots()
stats.probplot(data2, fit=True, plot=ax)
plt.show()

# %%
stats.shapiro(data2)
# Out:
# ShapiroResult(statistic=np.float64(0.9483384234928961), pvalue=np.float64(3.141452614369479e-18))
